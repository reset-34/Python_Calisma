# %%
# Asal Sayı Ayıklama

# Başlangıç Sayı Listesi 
numbers = [2,4,5,6,7,10,19,0]

# Asal Sayılar
prime_numbers = []

# Listede Gezinme 
for number in numbers:
    if number<2:
        continue
    
    is_prime = True
    #for i in range(2,number):
    for i in range(2,int (number**0.5)+1):  #kökünü alma **0.5 şeklinde yapılır 
        if number % i==0:
            is_prime = False
            break
    if is_prime:
        prime_numbers.append(number)
print ("Asal Sayılar: ", prime_numbers)
# Out:
# Asal Sayılar:  [2, 5, 7, 19]

# %%
# Asal Sayı Ayıklama  FONKSİYONLA YAPIMI

def is_prime ( number ):

    if number<2:
        return False
    

    #for i in range(2,number):
    for i in range(2,int (number**0.5)+1):  #kökünü alma **0.5 şeklinde yapılır 
        if number % i==0:
           return False
    return True
       


# Başlangıç Sayı Listesi 
numbers = [2,4,5,6,7,10,19,0]

# Asal Sayılar
prime_numbers = []

# Listede Gezinme 
for number in numbers:
    if is_prime (number):
        prime_numbers.append(number)
print ("Asal Sayılar: ", prime_numbers)
# Out:
# Asal Sayılar:  [2, 5, 7, 19]
