# %%
toplam = 0
while True:
    sayi = float (input("Sayi:"))
    if sayi== -1:
        break
    else:
        toplam+=sayi
            
print(f"Girilen Sayıların Toplamı: {toplam}")
# Out:
# Girilen Sayıların Toplamı: 9.0
