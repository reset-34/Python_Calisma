# %%
n = int (input ("Kaç Terimlik Bir Fibonavcci Oluşturmak İstiyorsunuz"))

if n<=0:
    print("Pozitif bir sayı girmelisiniz.")
else:
    print("Fibonacci serisini yazdır.")
    if n==1:
        print("0")
    elif n==2:
        print ("0,1")
    else:
        a,b= 0,1
        print ("0,1",end=",")
        for i in range (3, n+1):
            c = a+b
            print(c, end=", ")  #?
            a, b= b, c
# Out:
# Fibonacci serisini yazdır.
# 0,1,1,
