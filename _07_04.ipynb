# %%
sayi = 1
for sayi in range (1, 11):
    if (sayi%2==1):
        continue
    print (sayi)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
n = int (input ("Limit Değeri Giriniz: "))
i = 1
for i in range (1, n):
    if (i%2==1):
        continue
    print (i)
# Out:
# 2
# 4
