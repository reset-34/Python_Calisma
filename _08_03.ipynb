# %%
gizli_sayi = 45

deneme_sayisi = 0

while True:
    tahmin = int (input ("Tahmininizi Giriniz: "))
    deneme_sayisi += 1
    
    if tahmin < gizli_sayi:
        print ("Daha Büyük bir Tahmin yapınız.")
    elif tahmin > gizli_sayi:
        print ("Daha Küçük bir Tahmin yapınız.")
    else:
        print(f"Tebrikler ! {deneme_sayisi} adımda tahmin ettiniz.")
        break
# Out:
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Küçük bir Tahmin yapınız.
# Tebrikler ! 4 adımda tahmin ettiniz.

# %%
# rast gele sayı istersek random kullanımı 

import random

gizli_sayi = random.randint(1,100)

deneme_sayisi = 0

while True:
    tahmin = int (input ("Tahmininizi Giriniz: "))
    deneme_sayisi += 1
    
    if tahmin < gizli_sayi:
        print ("Daha Büyük bir Tahmin yapınız.")
    elif tahmin > gizli_sayi:
        print ("Daha Küçük bir Tahmin yapınız.")
    else:
        print(f"Tebrikler ! {deneme_sayisi} adımda tahmin ettiniz.")
        break
# Out:
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Küçük bir Tahmin yapınız.
# Daha Küçük bir Tahmin yapınız.
# Daha Küçük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Daha Büyük bir Tahmin yapınız.
# Tebrikler ! 20 adımda tahmin ettiniz.
