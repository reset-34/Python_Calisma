# %%
# İki Diziyi Birleştirme 

# girişleri al 

input_one = input ( "1. Sayı Listesini Giriniz: (Sayıları Ayırmak İçin Boşluk Kullanın )")
input_one = [int (num) for num in input_one.split()]

input_two = input ( "2. Sayı Listesini Giriniz: (Sayıları Ayırmak İçin Boşluk Kullanın )")
input_two = [int (num) for num in input_two.split()]


merged_list = input_one + input_two

print ( "1. Liste : ", input_one)
print( "2. Liste :", input_two)
print ( "Birleştirilmiş Liste : ",merged_list)
# Out:
# 1. Liste :  [2, 6, 8]
# 2. Liste : [4, 7, 9]
# Birleştirilmiş Liste :  [2, 6, 8, 4, 7, 9]
