# %%
matris = [[1,2,3],
          [4,5,6]]   # elle matris oluşturduk

# %%
matris
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
matris [0]
# Out:
# [1, 2, 3]

# %%
matris [1]
# Out:
# [4, 5, 6]

# %%
matris [0][0]
# Out:
# 1

# %%
type (matris[0])
# Out:
# list

# %%
matris = []
matris.append([1,2,3])
matris.append([2,3,4])
matris    #append yardımıyla aynı çıktıya erişebiliriz.
# Out:
# [[1, 2, 3], [2, 3, 4]]

# %%
numbers = list (range (1,7))
matris = [[0,0,0],[0,0,0]]
p= 0
for i in range (2):
    for j in range (3):
        matris [i] [j] = numbers[p]
        p+=1
        
print(matris)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
for i in range (2):  #satır
    for j in range (3):  #sütun
        print (f"{matris [i][j]:4d}", end='')
    print("")
# Out:
#    1   2   3
#    4   5   6

# %%
len (matris)  # satır sayısı
# Out:
# 2

# %%
print (f"Satır Sayısı: {len(matris)}")
# Out:
# Satır Sayısı: 2

# %%
print (f"Satır Sayısı: {len(matris)}")
print (f"Sütun Sayısı: {len(matris [0])}")
# Out:
# Satır Sayısı: 2
# Sütun Sayısı: 3
