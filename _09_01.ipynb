# %%
sayilar = [10, 5, 8, 9, 23, 55]

# %%
sayilar
# Out:
# [10, 5, 8, 9, 23, 55]

# %%
print (sayilar[0])
print (sayilar[3])
# Out:
# 10
# 9

# %%
isimler = ["ahmet","can","merve","filiz"]
print (isimler[-1])
print (isimler[-2])

# -1 -2 tersten getirmek istersek pythonun bir özelliği
# Out:
# filiz
# merve

# %%
karisik = [5, "merhaba", True, 3,15, False]
print (karisik)
# Out:
# [5, 'merhaba', True, 3, 15, False]

# %%
sayilar.append(-5)

# append diziye ekleme yapar aşağı bak

# %%
sayilar
# Out:
# [10, 5, 8, 9, 23, 55, -5]

# %%
# 1. kutuya 44 u eklemek istersek insert kullanıyoruz bu şekilde 

sayilar.insert (1,44)    # 1 eklenecek kutu 44 eklenecek rakkam
print(sayilar)
# Out:
# [10, 44, 5, 8, 9, 23, 55, -5]

# %%
cikarilan_eleman = sayilar.pop ()
print (cikarilan_eleman)

# en sondaki elemanı çıkartıyor son ekleneni
# Out:
# -5

# %%
sayilar

# sondaki -5 yok oldu
# Out:
# [10, 44, 5, 8, 9, 23, 55]

# %%
# birinci gözdeki elemanı sil yada ikinci dördüncü içinde pop kullanıyoruz şu şekilde 

sayilar.pop(0)
print(sayilar)
# Out:
# [44, 5, 8, 9, 23, 55]

# %%
# sıralı yapı isteyin ce sort kullanılır.
sayilar.sort()
print (sayilar)
# Out:
# [5, 8, 9, 23, 44, 55]

# %%
# büyükten küçüğe sıralama yapar reverse de 

sayilar.reverse()
print (sayilar)
# Out:
# [55, 44, 23, 9, 8, 5]

# %%
#diziyi bozmadan sadece bakmak için sıralı gösterim yapan sorted 

sayilar = sorted (sayilar)
print(sayilar)
# Out:
# [5, 8, 9, 23, 44, 55]

# %%
len (sayilar)
# Out:
# 6

# %%
# indis değilde doğrudan sayının kendisini verip yok etmeyi sağlar

sayilar.remove(9)
print(sayilar)
# Out:
# [5, 8, 23, 44, 55]
