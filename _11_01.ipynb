# %%
message = "Merhaba Dünya"
print (message)
print (type(message))
# Out:
# Merhaba Dünya
# <class 'str'>

# %%
# tırnak  ayrımı yok

name1 = 'Ali'
name2 = "Ahmet"
print(name1, name2)
# Out:
# Ali Ahmet

# %%
# tırnak ifadesini yansıtmak istersek böyle yazabiliriz.

sentence = "Ali dedi ki : 'Python öğreniyorum'"
print(sentence)
# Out:
# Ali dedi ki : 'Python öğreniyorum'

# %%
# illa  ' ' kullanacaksak  // lı ifade ile de olur 

sentence = 'Ali dedi ki : \'Python öğreniyorum \''
print(sentence)
# Out:
# Ali dedi ki : 'Python öğreniyorum '

# %%
# 3 tırnak ifadesiyle aşağıdaki gibi bir paragraf yazabiliyoruz. 

expression =  ''' Bu gün havagüzel.
Arkadaşlarla dışarı çıkabiliriz.
Güzel eğleniriz kahve de içeriz.
'''

print(expression)
# Out:
#  Bu gün havagüzel.
# Arkadaşlarla dışarı çıkabiliriz.
# Güzel eğleniriz kahve de içeriz.
