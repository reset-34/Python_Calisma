# %%
isimler = ["ahmet","can","merve","filiz"]

# %%
for isim in isimler:
    print(f"{isim}")
# Out:
# ahmet
# can
# merve
# filiz

# %%
for i in range (len(isimler)):
    print (f"{i}.eleman:{isimler[i].title ()}")
# Out:
# 0.eleman:Ahmet
# 1.eleman:Can
# 2.eleman:Merve
# 3.eleman:Filiz

# %%
for i in range (len(isimler)-1,-1,-1):
    print(i)
# Out:
# 3
# 2
# 1
# 0

# %%
for i in range (len(isimler)-1,-1,-1):
    print(f"{i}.eleman: {isimler[i]}")
# Out:
# 3.eleman: filiz
# 2.eleman: merve
# 1.eleman: can
# 0.eleman: ahmet

# %%
i=0
while i<len (isimler):
    print (f"{i}.isim: {isimler[i].title()}")
    i+=1
# Out:
# 0.isim: Ahmet
# 1.isim: Can
# 2.isim: Merve
# 3.isim: Filiz

# %%
i = len (isimler)-1
while i>=0:
    print (f"{i}.isim: {isimler[i].title()}")
    i-=1
# Out:
# 3.isim: Filiz
# 2.isim: Merve
# 1.isim: Can
# 0.isim: Ahmet

# %%
# itera edilebilir sıralanabilir anlamına gelir.

for index, isim in enumerate(isimler):
    print(f"{index}.isim: {isim}")
# Out:
# 0.isim: ahmet
# 1.isim: can
# 2.isim: merve
# 3.isim: filiz

# %%
for index, isim in enumerate (reversed(isimler)):
    print(f"{index}.isim: {isim.title()}")
    
    
    # ters çevirerek getirmek için reversed i kullandık.
# Out:
# 0.isim: Filiz
# 1.isim: Merve
# 2.isim: Can
# 3.isim: Ahmet

# %%
# diziler üzerinde gezinme

isimler = ["ahmet","can","merve","filiz"]

# %%
for isim in isimler:
    print (f"{isim}")
    
    #burada baştan sona bir gezinme sağlıyoruz
# Out:
# ahmet
# can
# merve
# filiz

# %%
# sayısal değerleri görüyoruz range  ve len (dizinin uzunluğu verir)  kullanarak 

for i in range (len(isimler)):
    print (f"{i}.eleman: {isimler[i].title()}")
# Out:
# 0.eleman: Ahmet
# 1.eleman: Can
# 2.eleman: Merve
# 3.eleman: Filiz

# %%
# tersden sıraladım -1 lerle

for i in range (len (isimler)-1,-1,-1):
    print (f"{i} . eleman: {isimler[i]}")
# Out:
# 3 . eleman: filiz
# 2 . eleman: merve
# 1 . eleman: can
# 0 . eleman: ahmet
