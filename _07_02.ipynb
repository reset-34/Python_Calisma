# %%
ifade = "Serap"
for karakter in ifade:
    print (karakter.upper())
    
    # upper büyük harf yap demek
# Out:
# S
# E
# R
# A
# P

# %%
for i in range (1,5+1):
    print (i)
    
    # +1 5 i de içine katar
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = int (input ("Limit Değerini Giriniz: "))
for i in range (1,n+1):
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range (1,10,2):
        print (i)
        
        # 2 olan 2 artarak gitsin demek
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range (2,10,3):
        print (i)
        
        # 2 den başlasın 10 a kadar 3 artırarak gitsin
# Out:
# 2
# 5
# 8
