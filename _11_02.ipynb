# %%
#Negatif ve Pozitif Sayıları Ayırma 
#girişler 
numbers = input ("Sayıları bir boşluk karakteri bırakarak giriniz :  (10 20 ....)" )
#tip dönüşümü
number_list = [int (num) for num in numbers.split()]
number_list

# pozitif sayılar için liste 
positive_numbers = []

# negatif sayılar için liste 
negative_numbers = []

# her bir sayıyı kontrol edicez
for number in number_list:
    if number > 0 : 
        positive_numbers.append(number)
    elif number < 0 : 
        negative_numbers.append(number)
    else:
        print ( "Sıfır Herhangi Bir Listeye Eklnmedi !")
        

# sonuçları göster 
print ("Pozitif Sayılar : ", positive_numbers)
print("Negatif Sayılar: ", negative_numbers)
# Out:
# Pozitif Sayılar :  [10, 2]
# Negatif Sayılar:  [-5, -4]

# %%
print (numbers)
print (type (numbers))

temp = numbers.split()
temp

nums = []
for item in temp :
    num = int (item)
    nums.append(num)
nums
# Out:
# -5 10 -4 2
# <class 'str'>
# [-5, 10, -4, 2]
