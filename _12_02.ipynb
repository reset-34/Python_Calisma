# %%
name = input ("Adınızı Giriniz : ")
name = name.lower()  # küçük harfe çevirir
print(name)
# Out:
# serap

# %%
name = input ("Adınızı Giriniz : ").lower()   #string döndüğü için direk böyle de lower deriz. 
print(name)
# Out:
# serap

# %%
word1 = "Merhaba"

# değer - referans (x)
word2 = word1  # yeni bir nesne oluşturuluyor | yeni referans

print(word1,word2)
word1 = "Hoşçakal"
print(word1,word2)
# Out:
# Merhaba Merhaba
# Hoşçakal Merhaba

# %%
l1 = [1,2,3]
l2 = l1 # value / referans / yeni nesne üretilmedi !
print(l1,l2)

l1.append(10)
l2.remove(1)
print(l1,l2)
# Out:
# [1, 2, 3] [1, 2, 3]
# [2, 3, 10] [2, 3, 10]

# %%
name = "Ömer"
print (name [0])
print (name [-1])
print (name [-2])
print (name [3])
# Out:
# Ö
# r
# e
# r

# %%
name [0] = "ö"    # BÖYLE BİR ATAMA YAPAMAYIZ !
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 name [0] = "ö"    # BÖYLE BİR ATAMA YAPAMAYIZ !
#
# TypeError: 'str' object does not support item assignment

# %%
print (len (name))
# Out:
# 4

# %%
names = ["ayşe","ali","can","mehmet"]
for name in names:
    print (f"Sıradaki Kişi: {name.upper()}")
# Out:
# Sıradaki Kişi: AYŞE
# Sıradaki Kişi: ALI
# Sıradaki Kişi: CAN
# Sıradaki Kişi: MEHMET

# %%
# Dilimleme 

sentence = "Programlama Öğreniyorum"
print (sentence[0:7])
print (sentence[4:])
print (sentence[:5])
print (sentence[::2])
# Out:
# Program
# ramlama Öğreniyorum
# Progr
# PormaaÖrnyrm

# %%
print (name)
print (name[::-1])
# Out:
# mehmet
# temhem

# %%
new_sentence = "Merhaba " +  name.title() +  " Bey. "
print (new_sentence)
# Out:
# Merhaba Mehmet Bey.

# %%
new_sentence = "Merhaba " +  name [:2].title() +  " Bey. "
print (new_sentence)
# Out:
# Merhaba Me Bey.

# %%
print(len (new_sentence))
print(new_sentence[0])
# Out:
# 16
# M

# %%
print(len (new_sentence))
print(new_sentence[17])
# Out:
# 16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(len (new_sentence))
# ----> 2 print(new_sentence[17])
#
# IndexError: string index out of range
